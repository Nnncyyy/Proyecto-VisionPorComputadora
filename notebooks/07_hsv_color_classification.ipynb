# %% [markdown]
# # M3-01/M3-02 — HSV para color y equipo

# %% [markdown]
# Este notebook ejecuta el detector HSV sobre el CSV de M2. Ajusta las rutas a tu video local.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
sys.path.insert(0, str(ROOT))
from src.color_utils import classify_tracks_with_hsv

video = ROOT / "data" / "raw" / "videoInstrucciones.mov"
tracks = ROOT / "outputs" / "metrics" / "tracks.csv"
out = ROOT / "outputs" / "metrics" / "tracks_with_color.csv"

df = classify_tracks_with_hsv(video, tracks, out, max_frames=180)
df.head()
