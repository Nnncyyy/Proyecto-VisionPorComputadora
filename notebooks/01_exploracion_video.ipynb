# %%
import sys
import os

# Agregamos la carpeta src al sistema para poder importar nuestra función
sys.path.append(os.path.abspath("../src"))
from video_utils import extraer_frames

# %%
# Definimos las rutas relativas desde la carpeta notebooks/
RUTA_VIDEO = "../data/raw/videoInstrucciones.mov"
DIRECTORIO_SALIDA = "../docs/assets/m1/frames/"

# Ejecutamos la extracción de 3 frames (saltando 50 frames entre cada uno)
extraer_frames(
    video_path=RUTA_VIDEO,
    output_dir=DIRECTORIO_SALIDA,
    num_frames=3,
    stride=50
)
# Out:
# ✅ Frame guardado en: ../docs/assets/m1/frames/frame_0001.jpg
# ✅ Frame guardado en: ../docs/assets/m1/frames/frame_0050.jpg
# ✅ Frame guardado en: ../docs/assets/m1/frames/frame_0100.jpg
#
# Extracción completada. Se guardaron 3 frames en ../docs/assets/m1/frames/
