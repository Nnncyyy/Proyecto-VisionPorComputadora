# %%
import sys
import os
import cv2
import ultralytics
import supervision as sv
from ultralytics import SAM

# Importar nuestras rutas
sys.path.append(os.path.abspath("../src"))
from config import MODEL_PATH

print("Versiones instaladas:")
print(f"Supervision: {sv.__version__}")
print(f"Ultralytics: {ultralytics.__version__}")
print(f"OpenCV: {cv2.__version__}\n")

if os.path.exists(MODEL_PATH):
    print(f"Cargando SAM 3 desde {MODEL_PATH}...")
    # Se carga usando la CPU para compatibilidad de hardware
    model = SAM(MODEL_PATH)
    print("SAM 3 cargado correctamente y listo para inferencia")
else:
    print(f"Error: No se encontró el archivo del modelo en {MODEL_PATH}")
    print("Recuerda descargar sam3.pt y colocarlo manualmente en la carpeta assets/")
# Out:
# Versiones instaladas:
# Supervision: 0.28.0
# Ultralytics: 8.4.57
# OpenCV: 4.13.0
#
# Cargando SAM 3 desde c:\Users\diego\OneDrive\Documentos\GitHub\Proyecto-VisionPorComputadora\assets\sam3.pt...
# SAM 3 cargado correctamente y listo para inferencia
