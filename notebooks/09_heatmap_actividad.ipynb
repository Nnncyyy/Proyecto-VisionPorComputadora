# %% [markdown]
# # M3-10 — Mapa de calor

# %% [markdown]
# Crea mapas de calor de actividad usando las trayectorias.

# %%
from pathlib import Path
import sys, pandas as pd
ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
sys.path.insert(0, str(ROOT))
from src.heatmap import create_heatmap_image

tracks = pd.read_csv(ROOT / "outputs" / "metrics" / "tracks_projected.csv")
out = ROOT / "outputs" / "figures" / "heatmap_activity.jpg"
create_heatmap_image(tracks, out)
print(out)
